# %% [markdown]
# # Regression algorithms
# Regression algorithms are a class of machine learning algorithms used for predicting continuous values based on input features. These algorithms are widely used in various fields such as finance, healthcare, and economics.

# %% [markdown]
# # Linear Regression
#
# Linear regression is one of the simplest and most commonly used regression algorithms. It assumes a linear relationship between the input features and the target variable. The goal is to find the best-fit line that minimizes the difference between the predicted and actual values.

# %% [markdown]
# ![Linear-Regression1.webp](attachment:Linear-Regression1.webp)

# %% [markdown]
# # Simple Linear Regression:
#
# Simple linear regression involves only one independent variable and one dependent variable.The relationship between the independent and dependent variables is assumed to be linear, and the model aims to find the best-fitting straight line that minimizes the sum of squared residuals.

# %% [markdown]
# # Multiple Linear Regression:
#
#     Multiple linear regression extends simple linear regression to cases where there are multiple independent variables. The model assumes a linear relationship between the dependent variable and each independent variable, with coefficients representing the strength and direction of these relationships.

# %% [markdown]
# # Polynomial Regression:
#
#     Polynomial regression involves fitting a polynomial function to the data instead of a straight line. This allows for capturing non-linear relationships between the independent and dependent variables.

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('placement2.csv')

df.shape[0]
# Out:
# 200

# %%
sns.scatterplot(x="cgpa",y='package',data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train,y_train)

# %%
X_test.iloc[29]
# Out:
# cgpa    5.12
# Name: 122, dtype: float64

# %%
y_test.tail(5)
# Out:
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
#Y_pred = mx + b

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-0.8961119222429144)

# %%
y_pred = m*5.88 + b

# %%
y_pred
# Out:
# array([2.38464568])

# %%
lr.predict(X_test.iloc[29].values.reshape(1,1))
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.96060218])

# %% [markdown]
# # Best Fit Line

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
class myLR:
    
    def __init__(self):
        self.m = None
        self.b = None
        
    def fit (self,x_train,y_train):
        num = 0
        deo = 0
        
        for i in range(x_train.shape[0]):
            num = num + ((x_train[i] - x_train.mean()) * (y_train[i] - y_train.mean()))
            deo = deo + ((x_train[i] - x_train.mean()) * (x_train[i] - x_train.mean()))
            
        self.m = num/deo
        self.b = y_train.mean() - (self.m * x_train.mean())
        print(self.m)
        print(self.b)
        
    def predict (self,x_test):
        
        return self.m * x_test + self.b

# %%
lr = myLR()

# %%
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr.fit(X_train,y_train)
# Out:
# 0.5579519734250721
# -0.8961119222429152

# %%
X_test[2]
# Out:
# np.float64(5.88)

# %%
y_test
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print(lr.predict(X_test[2]))
# Out:
# 2.3846456814965085
